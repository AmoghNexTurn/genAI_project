# %%
import os
import uuid
import requests
import json
import streamlit as st
from sentence_transformers import SentenceTransformer
from qdrant_client import QdrantClient
from qdrant_client.models import Distance, VectorParams, PointStruct
from dotenv import load_dotenv

load_dotenv()

# Constants
GROQ_MODEL = "meta-llama/llama-4-scout-17b-16e-instruct"
GROQ_API_KEY = os.getenv("GROQ_API_KEY")
collection_name = "battery_chunks"
client = QdrantClient(host="localhost", port=6333)
model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')

with open("evaluation_questions_tf.json", "r", encoding="utf-8") as f:
    tf_dataset = json.load(f)

def retrieve_context(question: str, top_k=20) -> str:
    query_vector = model.encode(question)
    response = client.query_points(
        collection_name=collection_name,
        query=query_vector,
        limit=top_k
    )
    retrieved = [point.payload.get("text") for point in response.points if point.payload.get("text")]
    return "\n\n".join(retrieved), response.points

def load_tf_prompt_template(path="evaluation_prompt_tf.txt") -> str:
    try:
        with open(path, "r", encoding="utf-8") as file:
            return file.read()
    except FileNotFoundError:
        raise FileNotFoundError(f"Prompt template file not found at: {path}")
    except Exception as e:
        raise RuntimeError(f"Failed to load prompt template: {e}")

def generate_true_false_prompt(context: str, query: str) -> str:
    template = load_tf_prompt_template()
    try:
        return template.format(context=context, query=query)
    except KeyError as e:
        raise KeyError(f"Missing placeholder in prompt template: {e}")

def ask_groq_llm(prompt, model=GROQ_MODEL, key=GROQ_API_KEY):
    url = "https://api.groq.com/openai/v1/chat/completions"
    headers = {
        "Authorization": f"Bearer {key}",
        "Content-Type": "application/json"
    }
    payload = {
        "model": model,
        "messages": [
            {"role": "system", "content": "You are a technical expert."},
            {"role": "user", "content": prompt}
        ],
        "temperature": 0.0
    }
    response = requests.post(url, headers=headers, json=payload)
    response.raise_for_status()
    return response.json()["choices"][0]["message"]["content"].strip().lower()

# Evaluation loop
correct = 0
total = len(tf_dataset)

import time

TP = FP = FN = TN = correct = 0
total = len(tf_dataset)

def normalize_result(result):
    return result.strip().lower().replace("**", "")

# %%
for i, item in enumerate(tf_dataset, 1):
    time.sleep(10)
    # i = 0
    # item = tf_dataset[i]
    query = item["question"]
    expected = "true" if item["answer"] else "false"

    context, _ = retrieve_context(query)
    prompt = generate_true_false_prompt(context, query)
    result = ask_groq_llm(prompt)

    result_normalized = normalize_result(result)
    is_correct = (result_normalized == expected)
    correct += is_correct

    # Update confusion matrix
    if expected == "true":
        if result_normalized == "true":
            TP += 1
        else:
            FN += 1
    else:
        if result_normalized == "true":
            FP += 1
        else:
            TN += 1

    print(f"{i}. Q: {query}")
    print(f"   Expected: {expected}, Got: {result_normalized}, Correct: {is_correct}\n")
# Out:
# 1. Q: Michael Faraday proposed in 1834 that every ampere flowing through an electrochemical cell corresponds to a matching chemical change.
#    Expected: true, Got: true, Correct: True
#
# 2. Q: The actual energy generated by a battery is calculated by multiplying amperes, time, and average voltage.
#    Expected: true, Got: true, Correct: True
#
# 3. Q: One chemical equivalent of zinc weighs approximately 87 grams.
#    Expected: false, Got: false, Correct: True
#
# 4. Q: One faraday of charge is equal to 96,485 coulombs.
#    Expected: true, Got: true, Correct: True
#
# 5. Q: A zinc and manganese dioxide cell operating at 1.2 volts produces approximately 32.2 watt-hours of energy per chemical equivalent discharged.
#    Expected: true, Got: true, Correct: True
#
# 6. Q: Zhang et al. developed nanocomposite paper supercapacitors using multi-walled carbon nanotubes embedded in micro-fibrillated cellulose.
#    Expected: true, Got: true, Correct: True
#
# 7. Q: The paper-based supercapacitor created by Zhang et al. had a specific capacitance of 154.5 mF cm at 20 mV s, measured by galvanostatic charge-discharge.
#    Expected: false, Got: false, Correct: True
#
# 8. Q: Hu et al.'s hybrid electrode used a configuration of cellulose paper/CNT/MnO2/CNT.
#    Expected: true, Got: true, Correct: True
#
# 9. Q: Hu et al. fabricated their hybrid electrode using a single-step spray coating method.
#    Expected: false, Got: false, Correct: True
#
# 10. Q: Liquid metal batteries do not contain combustible elements, making them unlikely to explode or flare out.
#    Expected: true, Got: false, Correct: False
#
# 11. Q: If a liquid metal battery is knocked over, it explodes due to the reactive nature of its components.
#    Expected: false, Got: false, Correct: True
#
# 12. Q: A major advantage of liquid metal batteries is their durability, with the potential to last for decades.
#    Expected: true, Got: true, Correct: True
#
# 13. Q: One faraday is equal to 96,485 coulombs of charge.
#    Expected: true, Got: true, Correct: True
#
# 14. Q: A cell operating at 1.2 volts producing one faraday gives 32.2 watt-hours.
#    Expected: true, Got: true, Correct: True
#
# 15. Q: Graphene has more than four times the tensile strength of steel while being flexible and lightweight.
#    Expected: true, Got: true, Correct: True
#
# 16. Q: Graphene is a poor conductor of heat and electricity, making it unsuitable for energy storage applications.
#    Expected: false, Got: false, Correct: True
#
# 17. Q: Capacitors store energy using chemical reactions within their electrodes.
#    Expected: false, Got: false, Correct: True
#
# 18. Q: The energy density of a typical capacitor is significantly lower than that of a lithium-ion battery.
#    Expected: true, Got: true, Correct: True
#
# 19. Q: Increasing the surface area of capacitor electrodes does not affect energy density.
#    Expected: false, Got: false, Correct: True
#
# 20. Q: One gram of graphene has a surface area approximately equal to 10 tennis courts.
#    Expected: true, Got: true, Correct: True
#
# 21. Q: Battery BAT-0001 has a capacity of 2459 mAh and a voltage of 3.41 V.
#    Expected: true, Got: false, Correct: False
#
# 22. Q: The efficiency of BAT-0015 is 98.98%.
#    Expected: true, Got: true, Correct: True
#
# 23. Q: BAT-0010 is a Solid-State battery with a degradation per 100 cycles of 0.62%.
#    Expected: false, Got: false, Correct: True
#
# 24. Q: BAT-0022 has a capacity of 2692 mAh and a degradation rate of 1.35% per 100 cycles.
#    Expected: true, Got: false, Correct: False
#
# 25. Q: BAT-0031 has a voltage of 3.75 V and a capacity of 1611 mAh.
#    Expected: true, Got: true, Correct: True
#
# 26. Q: The efficiency of BAT-0033 is 91.66% and its degradation per 100 cycles is 2.29%.
#    Expected: true, Got: false, Correct: False
#
# 27. Q: BAT-0019 is a Solid-State battery with a voltage of 3.88 V.
#    Expected: false, Got: false, Correct: True
#
# 28. Q: BAT-0030 has an efficiency of 92.07% and a charge cycle count of 431.
#    Expected: true, Got: false, Correct: False

# %%
# Final metrics
accuracy = correct / total * 100
precision = TP / (TP + FP) if (TP + FP) > 0 else 0
recall = TP / (TP + FN) if (TP + FN) > 0 else 0
f1 = (2 * precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

# Report
print(f"\nEvaluation Complete: Accuracy = {accuracy:.2f}% on {total} questions\n")
print(f"Precision: {precision:.2f}")
print(f"Recall:    {recall:.2f}")
print(f"F1 Score:  {f1:.2f}")
print(f"TP: {TP}, FP: {FP}, TN: {TN}, FN: {FN}")
# Out:
# Evaluation Complete: Accuracy = 89.29% on 28 questions
#
# Precision: 1.00
# Recall:    0.76
# F1 Score:  0.86
# TP: 16, FP: 0, TN: 9, FN: 5

# %%
with open("subjective_questions.json", "r", encoding="utf-8") as f:
    subj_dataset = json.load(f)

print(subj_dataset)
# Out:
# [{'question': 'What makes graphene a suitable material for use in supercapacitors?', 'answer': 'Graphene is highly conductive, extremely thin, and flexible, allowing it to maximize electrode surface area for efficient energy storage.'}, {'question': 'How do capacitors differ from batteries in storing energy?', 'answer': 'Capacitors store energy on the surface of electrodes without chemical reactions, enabling much faster charging compared to batteries.'}, {'question': 'Why is degradation per 100 cycles important in battery evaluation?', 'answer': "It indicates how quickly a battery's performance declines, helping assess its long-term stability and efficiency in repeated usage."}, {'question': 'What is the role of the Faraday constant in electrochemical cells?', 'answer': 'It relates the amount of electric charge per mole of electrons transferred during electrochemical reactions, essential for energy calculations.'}, {'question': 'Why are liquid metal batteries considered highly durable?', 'answer': 'They operate without solid electrodes, reducing mechanical stress and enabling decades of stable performance under thermal cycling conditions.'}, {'question': 'How does the surface area of electrodes impact capacitor performance?', 'answer': 'Larger electrode surface area increases the amount of energy stored, improving capacitance and overall energy density in capacitors.'}, {'question': 'Why is energy density lower in capacitors than in lithium-ion batteries?', 'answer': 'Capacitors store energy physically, not chemically, limiting the total energy stored per unit mass compared to lithium-ion batteries.'}, {'question': 'How does voltage influence the energy output of a battery?', 'answer': 'Higher voltage increases energy output when multiplied by current and time, contributing directly to total watt-hours delivered by a cell.'}, {'question': 'What advantage do solid-state batteries offer over traditional lithium-ion types?', 'answer': 'Solid-state batteries are safer, more energy dense, and have longer life due to their solid electrolytes and reduced risk of leakage.'}, {'question': "Why is graphene's surface area crucial in supercapacitor design?", 'answer': 'Its massive surface area enables high charge accumulation, improving energy storage capacity and charging speed significantly in compact volumes.'}, {'question': "What determines a battery's efficiency percentage?", 'answer': 'It reflects how much of the input energy is effectively stored and recovered during operation, excluding energy lost as heat or resistance.'}, {'question': 'How are charge cycles related to battery life?', 'answer': 'More charge cycles typically indicate a longer battery life, assuming minimal degradation occurs with each full charge and discharge cycle.'}, {'question': 'What is the freezing behavior of liquid metal batteries?', 'answer': 'When cooled, the liquid metal solidifies but can be reheated to resume operation, making it a reversible and safe feature.'}, {'question': 'Why is thermal stability important in battery materials?', 'answer': 'Thermal stability prevents overheating, explosions, or performance loss, especially in high-demand or fluctuating temperature environments.'}, {'question': 'How is specific capacitance measured in a supercapacitor?', 'answer': "It's calculated using cyclic voltammetry, relating the current response to voltage scan rate and electrode surface area characteristics."}, {'question': 'What benefits do cellulose-based substrates offer in paper supercapacitors?', 'answer': 'They provide flexibility, lightweight construction, and compatibility with conductive materials like CNTs for efficient, wearable energy devices.'}, {'question': 'Why are chemical equivalents important in battery chemistry?', 'answer': 'They define the exact mass of material involved in electron transfer, crucial for calculating energy storage and predicting reaction products.'}, {'question': 'What makes multi-walled carbon nanotubes useful in ene ...

# %%
def load_subj_prompt_template(path="evaluation_prompt_subj.txt") -> str:
    try:
        with open(path, "r", encoding="utf-8") as file:
            return file.read()
    except FileNotFoundError:
        raise FileNotFoundError(f"Prompt template file not found at: {path}")
    except Exception as e:
        raise RuntimeError(f"Failed to load prompt template: {e}")
    
def generate_subj_prompt(context: str, query: str) -> str:
    template = load_subj_prompt_template()
    try:
        return template.format(context=context, query=query)
    except KeyError as e:
        raise KeyError(f"Missing placeholder in prompt template: {e}")

def load_subj_judge_template(path="judge_prompt.txt") -> str:
    try:
        with open(path, "r", encoding="utf-8") as file:
            return file.read()
    except FileNotFoundError:
        raise FileNotFoundError(f"Prompt template file not found at: {path}")
    except Exception as e:
        raise RuntimeError(f"Failed to load prompt template: {e}")
    
def generate_judge_prompt(question: str, reference_answer: str, candidate_answer: str) -> str:
    template = load_subj_judge_template()
    try:
        return template.format(question = question, reference_answer = reference_answer, candidate_answer = candidate_answer)
    except KeyError as e:
        raise KeyError(f"Missing placeholder in prompt template: {e}")

# %%
for i, item in enumerate(subj_dataset, 1):
    time.sleep(10)
    # i = 0
    # item = tf_dataset[i]
    query = item["question"]
    expected_answer = item["answer"]

    context, _ = retrieve_context(query)
    prompt = generate_subj_prompt(context, query)
    result = ask_groq_llm(prompt)

    item['llm_answer'] = result
    print(query, expected_answer, result)
# Out:
# What makes graphene a suitable material for use in supercapacitors? Graphene is highly conductive, extremely thin, and flexible, allowing it to maximize electrode surface area for efficient energy storage. graphene's high surface area, electrical conductivity, and thermal management properties make it suitable for supercapacitors, enabling rapid charge/discharge and high energy density.
# How do capacitors differ from batteries in storing energy? Capacitors store energy on the surface of electrodes without chemical reactions, enabling much faster charging compared to batteries. capacitors store energy on electrode surfaces, not through chemical reactions like batteries, allowing for rapid charging but lower energy density, typically around 1/3 watt-hour per kilogram.
# Why is degradation per 100 cycles important in battery evaluation? It indicates how quickly a battery's performance declines, helping assess its long-term stability and efficiency in repeated usage. degradation per 100 cycles is crucial in battery evaluation as it measures capacity loss over time, indicating battery lifespan and performance reliability, essential for applications like electric vehicles.
# What is the role of the Faraday constant in electrochemical cells? It relates the amount of electric charge per mole of electrons transferred during electrochemical reactions, essential for energy calculations. the faraday constant relates the quantity of electrode material to the amount of electric power desired, with 96,485 coulombs of current equal to 26.8 ampere-hours.
# Why are liquid metal batteries considered highly durable? They operate without solid electrodes, reducing mechanical stress and enabling decades of stable performance under thermal cycling conditions. liquid metal batteries are highly durable due to the absence of solid components that can degrade over time, allowing them to last for decades with minimal performance degradation.
# How does the surface area of electrodes impact capacitor performance? Larger electrode surface area increases the amount of energy stored, improving capacitance and overall energy density in capacitors. increasing the surface area of electrodes in capacitors, such as with graphene, significantly enhances energy density, allowing them to store more energy while maintaining rapid charge and discharge capabilities.
# Why is energy density lower in capacitors than in lithium-ion batteries? Capacitors store energy physically, not chemically, limiting the total energy stored per unit mass compared to lithium-ion batteries. energy density in capacitors is lower due to storage on electrode surfaces, not through chemical reactions, resulting in about 1/3 watt-hour per kilogram, much less than lithium-ion batteries.
# How does voltage influence the energy output of a battery? Higher voltage increases energy output when multiplied by current and time, contributing directly to total watt-hours delivered by a cell. the voltage of a battery directly influences its energy output, with higher voltages producing more energy, measured in watt-hours, as voltage multiplied by current and time.
# What advantage do solid-state batteries offer over traditional lithium-ion types? Solid-state batteries are safer, more energy dense, and have longer life due to their solid electrolytes and reduced risk of leakage. solid-state batteries offer improved durability, immunity to dendrites, and potential for decades-long lifespan, addressing limitations of traditional lithium-ion batteries related to heat, degradation, and safety.
# Why is graphene's surface area crucial in supercapacitor design? Its massive surface area enables high charge accumulation, improving energy storage capacity and charging speed significantly in compact volumes. graphene's high surface area, equivalent to 2629 square meters per gram, enables efficient energy storage and rapid charge/discharge rates in supercapacitors, making it an ideal material.
# What determines a battery's efficiency percentage? It reflects how much of the input energy is effectively stored and recovered during operation, excluding energy lost as heat or resistance. a battery's efficiency percentage is largely determined by the properties and characteristics of the component materials used in assembling the batteries, as well as cell engineering and system integration.
# How are charge cycles related to battery life? More charge cycles typically indicate a longer battery life, assuming minimal degradation occurs with each full charge and discharge cycle. battery life is significantly impacted by charge cycles, with commercial batteries losing only a small fraction of 1 percent per cycle, allowing for hundreds of recharge cycles.
# What is the freezing behavior of liquid metal batteries? When cooled, the liquid metal solidifies but can be reheated to resume operation, making it a reversible and safe feature. the freezing behavior of liquid metal batteries is totally reversible; they can be restored to working condition simply by heating them up, with no degradation in performance.
# Why is thermal stability important in battery materials? Thermal stability prevents overheating, explosions, or performance loss, especially in high-demand or fluctuating temperature environments. thermal stability is crucial in battery materials to prevent overheating, which can cause a spontaneous reaction, leading to thermal runaway, fires, or explosions, and degrade battery performance.
# How is specific capacitance measured in a supercapacitor? It's calculated using cyclic voltammetry, relating the current response to voltage scan rate and electrode surface area characteristics. specific capacitance in a supercapacitor is typically measured in farads per gram (f g-1) or millifarads per centimeter squared (mf cm-2) using cyclic voltammetry or electrochemical impedance spectroscopy.
# What benefits do cellulose-based substrates offer in paper supercapacitors? They provide flexibility, lightweight construction, and compatibility with conductive materials like CNTs for efficient, wearable energy devices. cellulose-based substrates offer high surface area, flexibility, and biodegradability, enhancing the performance and sustainability of paper supercapacitors with improved capacitance and energy storage capabilities.
# Why are chemical equivalents important in battery chemistry? They define the exact mass of material involved in electron transfer, crucial for calculating energy storage and predicting reaction products. one chemical equivalent of each electrode produces one faraday, or 96,485 coulombs of current, crucial for calculating battery capacity and energy output in watt-hours.
# What makes multi-walled carbon nanotubes useful in energy devices? Their high conductivity and structural strength make them ideal for improving charge transport and mechanical stability in electrodes. their high electrical conductivity, mechanical strength, and surface area make multi-walled carbon nanotubes useful in energy devices, such as batteries and supercapacitors, for enhanced performance and efficiency.
# How does electrode degradation affect overall battery performance? Degraded electrodes reduce capacity, increase internal resistance, and shorten cycle life, negatively impacting battery efficiency and reliability. electrode degradation significantly impacts battery performance, reducing capacity, voltage, and overall lifespan, with factors like material changes, oxidation, and ion diffusion affecting electrode efficiency and stability.
# What role does Na2SO4 play in three-electrode electrochemical testing? It serves as the electrolyte, enabling ion transport and supporting stable electrochemical reactions during electrode performance evaluation. na2so4 serves as a supporting electrolyte in three-electrode electrochemical testing, enhancing ionic conductivity and facilitating electron transfer during electrochemical reactions.

# %%
print(subj_dataset)
# Out:
# [{'question': 'What makes graphene a suitable material for use in supercapacitors?', 'answer': 'Graphene is highly conductive, extremely thin, and flexible, allowing it to maximize electrode surface area for efficient energy storage.', 'llm_answer': "graphene's high surface area, electrical conductivity, and thermal management properties make it suitable for supercapacitors, enabling rapid charge/discharge and high energy density."}, {'question': 'How do capacitors differ from batteries in storing energy?', 'answer': 'Capacitors store energy on the surface of electrodes without chemical reactions, enabling much faster charging compared to batteries.', 'llm_answer': 'capacitors store energy on electrode surfaces, not through chemical reactions like batteries, allowing for rapid charging but lower energy density, typically around 1/3 watt-hour per kilogram.'}, {'question': 'Why is degradation per 100 cycles important in battery evaluation?', 'answer': "It indicates how quickly a battery's performance declines, helping assess its long-term stability and efficiency in repeated usage.", 'llm_answer': 'degradation per 100 cycles is crucial in battery evaluation as it measures capacity loss over time, indicating battery lifespan and performance reliability, essential for applications like electric vehicles.'}, {'question': 'What is the role of the Faraday constant in electrochemical cells?', 'answer': 'It relates the amount of electric charge per mole of electrons transferred during electrochemical reactions, essential for energy calculations.', 'llm_answer': 'the faraday constant relates the quantity of electrode material to the amount of electric power desired, with 96,485 coulombs of current equal to 26.8 ampere-hours.'}, {'question': 'Why are liquid metal batteries considered highly durable?', 'answer': 'They operate without solid electrodes, reducing mechanical stress and enabling decades of stable performance under thermal cycling conditions.', 'llm_answer': 'liquid metal batteries are highly durable due to the absence of solid components that can degrade over time, allowing them to last for decades with minimal performance degradation.'}, {'question': 'How does the surface area of electrodes impact capacitor performance?', 'answer': 'Larger electrode surface area increases the amount of energy stored, improving capacitance and overall energy density in capacitors.', 'llm_answer': 'increasing the surface area of electrodes in capacitors, such as with graphene, significantly enhances energy density, allowing them to store more energy while maintaining rapid charge and discharge capabilities.'}, {'question': 'Why is energy density lower in capacitors than in lithium-ion batteries?', 'answer': 'Capacitors store energy physically, not chemically, limiting the total energy stored per unit mass compared to lithium-ion batteries.', 'llm_answer': 'energy density in capacitors is lower due to storage on electrode surfaces, not through chemical reactions, resulting in about 1/3 watt-hour per kilogram, much less than lithium-ion batteries.'}, {'question': 'How does voltage influence the energy output of a battery?', 'answer': 'Higher voltage increases energy output when multiplied by current and time, contributing directly to total watt-hours delivered by a cell.', 'llm_answer': 'the voltage of a battery directly influences its energy output, with higher voltages producing more energy, measured in watt-hours, as voltage multiplied by current and time.'}, {'question': 'What advantage do solid-state batteries offer over traditional lithium-ion types?', 'answer': 'Solid-state batteries are safer, more energy dense, and have longer life due to their solid electrolytes and reduced risk of leakage.', 'llm_answer': 'solid-state batteries offer improved durability, immunity to dendrites, and potential for decades-long lifespan, addressing limitations of traditional lithium-ion batteries related to heat, degradation, and safety.'}, {'question': "W ...

# %%
scores = []
for i, item in enumerate(subj_dataset, 1):
    time.sleep(5)
    question = item['question']
    reference_answer = item['answer']
    candidate_answer = item['llm_answer']
    prompt = generate_judge_prompt(question, reference_answer, candidate_answer)
    result = ask_groq_llm(prompt)
    scores.append(result)
    print(result)
# Out:
# 5
# 5
# 5
# 3
# 5
# 5
# 5
# 5
# 5
# 5
# 4
# 4
# 5
# 5
# 4
# 4
# 4
# 5
# 4
# 5

# %%
for i in range(len(scores)):
    scores[i] = int(scores[i])
print("Subjective accuracy as judged by the LLM:", (sum(scores)*0.2)/len(scores))
# Out:
# Subjective accuracy as judged by the LLM: 0.9200000000000002
